# %% [markdown]
# <a href="https://colab.research.google.com/github/VietHoangg03/Machine_Learning_Basic/blob/main/Histogram_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

cat_image = cv2.imread("binary_cat.png", 0)
cv2_imshow(cat_image)
# Out:
# <PIL.Image.Image image mode=L size=480x301>

# %%
counts = dict()
height, width = cat_image.shape
for row in range(height):
  for col in range(width):
    counts[cat_image[row, col]] = counts.get(cat_image[row,col],0) + 1

print('Count: ', counts)
# Out:
# Count:  {np.uint8(255): 54497, np.uint8(0): 89983}

# %%
import matplotlib.pyplot as plt

names = list(counts.keys())
values = list(counts.values())

plt.bar(range(len(counts)), values, tick_label=names)
plt.show()
